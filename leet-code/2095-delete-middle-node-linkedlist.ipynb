# %% [markdown]
# submission simple: https://leetcode.com/problems/delete-the-middle-node-of-a-linked-list/submissions/1427694099/?envType=study-plan-v2&envId=leetcode-75
#
# submission two pointers: https://leetcode.com/problems/delete-the-middle-node-of-a-linked-list/submissions/1427698203/?envType=study-plan-v2&envId=leetcode-75
#
# https://leetcode.com/problems/delete-the-middle-node-of-a-linked-list/description/?envType=study-plan-v2&envId=leetcode-75
#
# You are given the head of a linked list. Delete the middle node, and return the head of the modified linked list.
#
# The middle node of a linked list of size n is the ⌊n / 2⌋th node from the start using 0-based indexing, where ⌊x⌋ denotes the largest integer less than or equal to x.
#
# For n = 1, 2, 3, 4, and 5, the middle nodes are 0, 1, 1, 2, and 2, respectively.
#
# Input: head = [1,3,4,7,1,2,6]
# Output: [1,3,4,1,2,6]
# Explanation:
# The above figure represents the given linked list. The indices of the nodes are written below.
# Since n = 7, node 3 with value 7 is the middle node, which is marked in red.
# We return the new list after removing this node.
#
# Input: head = [1,2,3,4]
# Output: [1,2,4]
# Explanation:
# The above figure represents the given linked list.
# For n = 4, node 2 with value 3 is the middle node, which is marked in red.
#
# Input: head = [2,1]
# Output: [2]
# Explanation:
# The above figure represents the given linked list.
# For n = 2, node 1 with value 1 is the middle node, which is marked in red.
# Node 0 with value 2 is the only node remaining after removing node 1.
#
# Constraints:
#
# The number of nodes in the list is in the range [1, 105].
# 1 <= Node.val <= 105

# %% [markdown]
# O(N) two pointers

# %%
from typing import Optional

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteMiddle(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if not head.next: return

        slow, fast = head, head

        while fast and fast.next:
            slow = slow.next
            if fast.next and fast.next.next:
                fast=fast.next.next
            else:
                fast=fast.next

        if slow.next:
            slow.val=slow.next.val
            slow.next=slow.next.next
        else:
            head.next=None
        return head

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# O(N) simple

# %%
from typing import Optional

# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteMiddle(self, head: Optional[ListNode]) -> Optional[ListNode]:
        n = 1
        next = head.next
        if next is None:
            return None
        while next:
            next = next.next
            n += 1
        
        mid = n // 2

        next = head
        n = 1

        while n < mid:
            next = next.next
            n += 1

        nextnext = next.next
        if nextnext:
            if nextnext.next:
                next.next = nextnext.next
            else: next.next = None
        return head

# %% [markdown]
# ![image.png](attachment:image.png)
