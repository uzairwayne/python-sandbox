# %%
import firebase_admin
from firebase_admin import credentials, firestore
import os
import random
import pandas as pd

# %%
os.environ["FIRESTORE_EMULATOR_HOST"] = "host.docker.internal:8081"
os.environ["FIRESTORE_PROJECT_ID"] = "peakflo"
# os.environ["FIREBASE_PROJECT_ID"] = "peakflo"
# os.environ["FIREBASE_API_KEY"] = "AIzaSyDrBPSrW3t67cwO2wdfgR6lmyBG-iWC_cE"
# os.environ["FIREBASE_SERVICE_ACCOUNT"] = "firebase-adminsdk-a6keu@peakflo.iam.gserviceaccount.com"

# %%
# # Initialize the app with your service account key
if not firebase_admin._apps:
  cred = credentials.Certificate("./_serviceAccount.json")
  firebase_admin.initialize_app(cred,name="myuniquenameapp2")

# %%
# Initialize Firestore
db = firestore.client(firebase_admin.get_app(name='myuniquenameapp2'))

# %%
# Collection reference
collection_ref = db.collection('netsuite-bill-outgoing-updates')

billIds = ["XNP6FgzTJ1F3lIeofB5IC9PjKyiHap", "lq3HMCG2YsGa2Zh59yvpgvcFv4bTkM", "LL3dKIKRtebPA4LJej2k8PhGtPc8ok", "tGghN4CDVieDcZe8QXqLIjOXXokK6S", "u0GfJLljrTYVqWuzUEzTBJ8bDEPhHR", "pw7rgLTgaYYHAK7fkh4PeIH6J8ACsm", "9BikbUYBv1BTzWohEbIdQoxFEaUNOA", "vzx5ngZIObpy5ZcYeHrhw70wH2Vyn6", "sKCP1ZOFIEfz6p05zJ3DemSoazCCHV", "1JzAPa3WudWqrz7WrrvExlrY4VjCA2"]

# Create 10 documents to push
for i in range(10):
    billNumberUnique = random.randint(1000000000000, 10000000000000) + i;
    # Define the document data
    doc_data = {
        "action": "create",
        "type": "BILL",
        "updatedAt": firestore.SERVER_TIMESTAMP,
        "status": "ready",
        "vendorId": "wFW2BNhegaFQBM0TTboR",
        "billId": billIds[i],
        "billNumber": f"Test Bill From Local {billNumberUnique}",
        "notes": f"Test Bill From Local {billNumberUnique}",
        "currency": "SGD",
        "dueDate": "2024-08-30T07:14:24+00:00",
        "date": "2024-08-23T07:14:24+00:00",
        "lineItems": [{
            "accountId": "Ovgtbw5GVWPeM0tzm3VU",
            "total": 121 + i,
            "name": "test place holder line item name"
        }],
        "customerId": "demo1Company"
    }
    # Add the document to Firestore
    collection_ref.add(doc_data)

print("10 documents have been added to Firestore.")
# Out:
# 10 documents have been added to Firestore.

# %%
# import time
# import random
# print(round(time.time()))
# print(round(time.time()))

# print(random.randint(1000000000000, 10000000000000))
# print(random.randint(1000000000000, 10000000000000))
# print(random.randint(1000000000000, 10000000000000))
# print(random.randint(1000000000000, 10000000000000))

# print(firestore.SERVER_TIMESTAMP)

collection_ref = db.collection('netsuite-bill-outgoing-updates')


# Fetch all documents and collect into a list of dictionaries
documents = []
try:
    docs = collection_ref.stream()
    
    for doc in docs:
        doc_dict = doc.to_dict()
        doc_dict['id'] = doc.id  # Optionally include the document ID in the data
        documents.append(doc_dict)

    # Convert list of dictionaries to a pandas DataFrame
    df = pd.DataFrame(documents)
    # Select specific columns to display
    # columns_to_display = ['id', 'status', 'billNumber', 'sourceId']  # Replace with actual column names
    # df = df[columns_to_display]

except Exception as e:
    print(f"An error occurred: {e}")

df
# Out:
#                            billNumber              vendorId  type  sourceId  \
# 0  Test Bill From Local 3750289395222  wFW2BNhegaFQBM0TTboR  BILL     61346
# 1  Test Bill From Local 8358965890772  wFW2BNhegaFQBM0TTboR  BILL     61341
# 2  Test Bill From Local 4303450306964  wFW2BNhegaFQBM0TTboR  BILL     61344
# 3  Test Bill From Local 7802777782462  wFW2BNhegaFQBM0TTboR  BILL     61347
# 4  Test Bill From Local 7894461875882  wFW2BNhegaFQBM0TTboR  BILL     61345
# 5  Test Bill From Local 4486479021861  wFW2BNhegaFQBM0TTboR  BILL     61348
# 6  Test Bill From Local 2708274290091  wFW2BNhegaFQBM0TTboR  BILL     61342
# 7  Test Bill From Local 5118748875604  wFW2BNhegaFQBM0TTboR  BILL     61350
# 8  Test Bill From Local 4470297886995  wFW2BNhegaFQBM0TTboR  BILL     61349
# 9  Test Bill From Local 6839978236759  wFW2BNhegaFQBM0TTboR  BILL     61343
#
#   failureReason     status                        updatedAt  \
# 0                completed 2024-08-23 21:00:06.612000+00:00
# ...

# %%
billSourceIds = df['sourceId'].tolist()
billNumbers = df['billNumber'].tolist()
billIds = df['billId'].tolist()
totalPaymentAmounts = df['lineItems'].apply(lambda x: x[0]['total'] if isinstance(x, list) and len(x) > 0 and 'total' in x[0] else None).tolist()
manualPaymentIds = ["AtoJyKh7NcJsicq1NAgfmzsWDxEhua", "7OxhO0XbsKj75C7ewBjnD9083gA4wu", "p6TMwMwnByfyWPZSJv3eJoZhSDtpex", "uEujmgHpi7xxZsIWl1nThtuUKBsKXy", "TlYuWrBGdNOO6gSVowuFENlp8yDXCq", "8NIVWQ8msJYnnjVhe201BFCPLepdtr", "vmSwbRlzzflEdicEpMHPGzYv2wVm5a", "Tfbb07AzrTrmxvxylT3WWpZijk24C5", "cE3JMYBtC5k6uGNUBhZGRMZ4lhvWkd", "QYNMGbdrjVZzBTtUAl8UP1NOtISgeX"]

# %%
# Collection reference
collection_ref = db.collection('netsuite-bill-payment-outgoing-updates')

# Create 10 documents to push
for i in range(10):
    # Define the document data
    doc_data = {
        "action": "create",
        "manualPayment": {
            "accountId": "334"
        },
        "updatedAt": firestore.SERVER_TIMESTAMP,
        "status": "ready",
        "vendorId": "wFW2BNhegaFQBM0TTboR",
        "billSourceId": billSourceIds[i],
        "paymentAmount": totalPaymentAmounts[i],
        "currency": "SGD",
        "date": "2024-08-24T07:14:24+00:00",
        "customerId": "demo1Company",
        "fxRate": 1,
        "manualPaymentId": manualPaymentIds[i]
    }
    # Add the document to Firestore
    collection_ref.add(doc_data)

print("10 documents have been added to Firestore.")
# Out:
# 10 documents have been added to Firestore.
